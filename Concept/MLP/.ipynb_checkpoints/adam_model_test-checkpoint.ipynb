# %% [markdown]
# # adam_model_test.ipynb
# Description   : Multiple layer perceptron to solve general problems<br>

# %%
# %run adam_model.ipynb
# %run dataset_abalone.ipynb
# %run dataset_pulsar.ipynb
# %run dataset_pulsarselect.ipynb
# %run dataset_steel.ipynb
# %run dataset_flowers.ipynb
# %run dataset_office31.ipynb

# %%
od = Office31Dataset()

om1 = AdamModel('office31_model_1', od, [64,32,10])
om1.use_adam = True
om1.exec_all(epoch_count = 20, report = 10, learning_rate = 0.001)
# Out:
# Model office31_model_1 train started:
# Epoch 10: cost=4.332, accuracy=0.686+0.041/0.680+0.030 (325/325 secs)
# Epoch 20: cost=4.596, accuracy=0.686+0.039/0.640+0.020 (369/694 secs)
# Model office31_model_1 train ended in 694 secs:
# Model office31_model_1 test report: accuracy = 0.680 + 0.038, (0 secs)
# Model office31_model_1 Visualization
# [도메인 추정결과]
# 추정확률분포 [70,10,20] => 추정 amazon : 정답 amazon => O
# 추정확률분포 [70,10,20] => 추정 amazon : 정답 amazon => O
# 추정확률분포 [70,10,20] => 추정 amazon : 정답 dslr => X
# [상품 추정결과]
# 추정확률분포 [ 3, 1, 2, 0, 0, 2, 3, 2,...] => 추정 laptop_computer : 정답 headphones => X
# 추정확률분포 [ 3, 1, 2, 0, 0, 2, 3, 2,...] => 추정 laptop_computer : 정답 headphones => X
# 추정확률분포 [ 3, 1, 2, 0, 0, 2, 3, 2,...] => 추정 laptop_computer : 정답 file_cabinet => X

# %%
om2 = AdamModel('office31_model_2', od, [64,32,10])
om2.use_adam = False
om2.exec_all(epoch_count = 20, report = 10, learning_rate = 0.001)
# Out:
# Model office31_model_2 train started:
# Epoch 10: cost=3.371, accuracy=0.829+0.167/0.850+0.150 (99/99 secs)
# Epoch 20: cost=3.055, accuracy=0.857+0.220/0.880+0.200 (100/199 secs)
# Model office31_model_2 train ended in 199 secs:
# Model office31_model_2 test report: accuracy = 0.842 + 0.222, (0 secs)
# Model office31_model_2 Visualization
# [도메인 추정결과]
# 추정확률분포 [70, 9,22] => 추정 amazon : 정답 webcam => X
# 추정확률분포 [21,21,57] => 추정 webcam : 정답 webcam => O
# 추정확률분포 [96, 2, 3] => 추정 amazon : 정답 amazon => O
# [상품 추정결과]
# 추정확률분포 [ 0, 1, 1, 4, 3, 4, 6, 3,...] => 추정 ring_binder : 정답 bottle => X
# 추정확률분포 [ 0,26, 0, 3, 3, 2, 2,12,...] => 추정 bike : 정답 desk_chair => X
# 추정확률분포 [ 0, 1, 2, 2, 1, 3, 1, 2,...] => 추정 stapler : 정답 pen => X
