# %%
# %run mlp_model.ipynb
# %run dataset_abalone.ipynb
# %run dataset_pulsar.ipynb
# %run dataset_pulsarselect.ipynb
# %run dataset_steel.ipynb
# %run dataset_flowers.ipynb

# %%
ad = AbaloneDataset()
am = MlpModel('abalone_model', ad, [])
am.exec_all(epoch_count=10, report=2)
# Out:
# Model abalone_model train started:
#     Epoch 2: cost=8.163, accuracy=0.734/0.762 (0/0 secs)
#     Epoch 4: cost=7.381, accuracy=0.745/0.733 (1/1 secs)
#     Epoch 6: cost=7.241, accuracy=0.748/0.719 (0/1 secs)
#     Epoch 8: cost=7.138, accuracy=0.750/0.777 (0/1 secs)
#     Epoch 10: cost=7.055, accuracy=0.750/0.754 (0/1 secs)
# Model abalone_model train ended in 1 secs:
# Model abalone_model test report: accuracy = 0.723, (0 secs)
#
# Model abalone_model Visualization
# [0.00,1.00,0.00,0.69,0.54,0.20,1.69,0.77,0.36,0.48] => 추정 13.3 : 정답 11.0
# [0.00,1.00,0.00,0.69,0.53,0.19,1.73,0.76,0.44,0.46] => 추정 13.4 : 정답 11.0
# [1.00,0.00,0.00,0.46,0.35,0.11,0.40,0.18,0.08,0.12] => 추정  8.0 : 정답  7.0

# %%
ad = AbaloneDataset()
am = MlpModel('abalone_model', ad ,[5,3])
am.exec_all(epoch_count=1000, report=200,\
            batch_size=100, learning_rate=0.003,\
            show_cnt=5)
# Out:
# Model abalone_model train started:
#     Epoch 200: cost=4.821, accuracy=0.781/0.785 (1/1 secs)
#     Epoch 400: cost=4.655, accuracy=0.784/0.788 (2/3 secs)
#     Epoch 600: cost=4.486, accuracy=0.789/0.794 (2/5 secs)
#     Epoch 800: cost=4.426, accuracy=0.790/0.806 (1/6 secs)
#     Epoch 1000: cost=4.380, accuracy=0.792/0.838 (2/8 secs)
# Model abalone_model train ended in 8 secs:
# Model abalone_model test report: accuracy = 0.782, (0 secs)
#
# Model abalone_model Visualization
# [1.00,0.00,0.00,0.38,0.27,0.10,0.20,0.09,0.04,0.06] => 추정  6.7 : 정답  5.0
# [0.00,1.00,0.00,0.34,0.26,0.08,0.17,0.06,0.04,0.05] => 추정  7.9 : 정답 10.0
# [0.00,1.00,0.00,0.67,0.55,0.17,1.25,0.47,0.25,0.40] => 추정 14.3 : 정답 21.0
# [0.00,1.00,0.00,0.38,0.29,0.12,0.28,0.12,0.07,0.09] => 추정  8.9 : 정답  9.0
# [0.00,1.00,0.00,0.61,0.47,0.15,1.07,0.44,0.26,0.31] => 추정 11.6 : 정답 11.0

# %%
print(am)
am.visualize(5)
# Out:
# abalone_model/abalone(regression, 3340+629+208)
# Model abalone_model Visualization
# [0.00,1.00,0.00,0.65,0.52,0.17,1.56,0.71,0.36,0.40] => 추정 11.2 : 정답  8.0
# [0.00,0.00,1.00,0.41,0.30,0.10,0.36,0.17,0.07,0.11] => 추정  8.2 : 정답 11.0
# [0.00,1.00,0.00,0.78,0.63,0.25,2.78,1.35,0.76,0.58] => 추정 11.5 : 정답 12.0
# [0.00,0.00,1.00,0.42,0.33,0.12,0.41,0.16,0.08,0.14] => 추정 10.0 : 정답  8.0
# [0.00,1.00,0.00,0.55,0.39,0.13,0.73,0.34,0.16,0.19] => 추정  8.8 : 정답  8.0

# %%
pd = PulsarDataset()
pm = MlpModel('pulsar_model', pd, [5])
pm.exec_all(show_cnt=4)
# Out:
# Model pulsar_model train ended in 3 secs:
# Model pulsar_model test report: accuracy = 0.972, (0 secs)
#
# Model pulsar_model Visualization
# [102.0, 42.8,  0.6,...] => 추정 별(확률 0.01) : 정답 별 => O
# [129.5, 53.7,  0.0,...] => 추정 별(확률 0.00) : 정답 별 => O
# [107.5, 49.0,  0.5,...] => 추정 별(확률 0.08) : 정답 펄서 => X
# [112.0, 58.0,  0.1,...] => 추정 별(확률 0.01) : 정답 별 => O

# %%
pd = PulsarDataset()
pm = MlpModel('pulsar_model', pd, [10,5])
pm.exec_all(epoch_count=100,report=10,show_cnt=4)
pm.visualize(5)
# Out:
# Model pulsar_model train started:
#     Epoch 10: cost=0.095, accuracy=0.970/0.980 (3/3 secs)
#     Epoch 20: cost=0.090, accuracy=0.972/0.970 (3/6 secs)
#     Epoch 30: cost=0.088, accuracy=0.974/0.980 (4/10 secs)
#     Epoch 40: cost=0.087, accuracy=0.974/0.950 (3/13 secs)
#     Epoch 50: cost=0.086, accuracy=0.975/0.970 (4/17 secs)
#     Epoch 60: cost=0.085, accuracy=0.975/0.980 (4/21 secs)
#     Epoch 70: cost=0.085, accuracy=0.975/0.960 (3/24 secs)
#     Epoch 80: cost=0.085, accuracy=0.975/0.970 (4/28 secs)
#     Epoch 90: cost=0.084, accuracy=0.976/0.980 (3/31 secs)
#     Epoch 100: cost=0.084, accuracy=0.976/0.970 (3/34 secs)
# Model pulsar_model train ended in 34 secs:
# Model pulsar_model test report: accuracy = 0.973, (0 secs)
#
# Model pulsar_model Visualization
# [105.4, 44.5,  0.5,...] => 추정 별(확률 0.03) : 정답 별 => O
# [106.1, 39.1,  0.4,...] => 추정 별(확률 0.04) : 정답 별 => O
# [117.9, 61.9,  0.5,...] => 추정 별(확률 0.03) : 정답 별 => O
# [ 76.5, 34.1,  2.0,...] => 추정 펄서(확률 0.85) : 정답 펄서 => O
# Model pulsar_model Visualization
# [146.7, 49.2, -0.5,...] => 추정 별(확률 0.00) : 정답 별 => O
# [113.2, 45.1,  0.1,...] => 추정 별(확률 0.00) : 정답 별 => O
# [ 76.5, 34.1,  2.0,...] => 추정 펄서(확률 0.85) : 정답 펄서 => O
# [ 35.6, 42.1,  3.6,...] => 추정 펄서(확률 0.98) : 정답 펄서 => O
# [115.2, 55.8,  0.2,...] => 추정 별(확률 0.00) : 정답 별 => O

# %%
sd = SteelDataset()
sm = MlpModel('steel_model', sd, [12,7])
sm.exec_all(epoch_count=50, report=10)
# Out:
# Model steel_model train started:
#     Epoch 10: cost=1.854, accuracy=0.341/0.381 (0/0 secs)
#     Epoch 20: cost=1.793, accuracy=0.341/0.381 (1/1 secs)
#     Epoch 30: cost=1.756, accuracy=0.341/0.381 (0/1 secs)
#     Epoch 40: cost=1.732, accuracy=0.341/0.381 (1/2 secs)
#     Epoch 50: cost=1.717, accuracy=0.341/0.381 (0/2 secs)
# Model steel_model train ended in 2 secs:
# Model steel_model test report: accuracy = 0.367, (0 secs)
#
# Model steel_model Visualization
# 추정확률분포 [10,11,17, 8, 7,18,29] => 추정 Other_Faults : 정답 Pastry => X
# 추정확률분포 [10,11,17, 8, 7,18,29] => 추정 Other_Faults : 정답 Pastry => X
# 추정확률분포 [10,11,17, 8, 7,18,29] => 추정 Other_Faults : 정답 Other_Faults => O

# %%
sd = SteelDataset()
sm = MlpModel('steel_model', sd, [12,7,5])
sm.exec_all(epoch_count=100, report=20,learning_rate= 0.003)
# Out:
# Model steel_model train started:
#     Epoch 20: cost=1.696, accuracy=0.335/0.402 (1/1 secs)
#     Epoch 40: cost=1.672, accuracy=0.335/0.402 (2/3 secs)
#     Epoch 60: cost=1.667, accuracy=0.335/0.402 (2/5 secs)
#     Epoch 80: cost=1.666, accuracy=0.335/0.402 (1/6 secs)
#     Epoch 100: cost=1.665, accuracy=0.335/0.402 (2/8 secs)
# Model steel_model train ended in 8 secs:
# Model steel_model test report: accuracy = 0.391, (0 secs)
#
# Model steel_model Visualization
# 추정확률분포 [ 8,10,21, 4, 3,22,33] => 추정 Other_Faults : 정답 Other_Faults => O
# 추정확률분포 [ 8,10,21, 4, 3,22,33] => 추정 Other_Faults : 정답 Bumps => X
# 추정확률분포 [ 8,10,21, 4, 3,22,33] => 추정 Other_Faults : 정답 Other_Faults => O

# %%
psd = PulsarSelectDataset()
psm = MlpModel('pulsar_select_model', psd, [12,7,5])
psm.exec_all(epoch_count=100, report=20,learning_rate= 0.003)
# Out:
# Model pulsar_select_model train started:
#     Epoch 20: cost=0.094, accuracy=0.974/0.990 (11/11 secs)
#     Epoch 40: cost=0.088, accuracy=0.973/0.990 (14/25 secs)
#     Epoch 60: cost=0.086, accuracy=0.974/0.980 (18/43 secs)
#     Epoch 80: cost=0.085, accuracy=0.974/0.970 (16/59 secs)
#     Epoch 100: cost=0.084, accuracy=0.975/0.980 (12/71 secs)
# Model pulsar_select_model train ended in 71 secs:
# Model pulsar_select_model test report: accuracy = 0.972, (0 secs)
#
# Model pulsar_select_model Visualization
# 추정확률분포 [100, 0] => 추정 별 : 정답 별 => O
# 추정확률분포 [100, 0] => 추정 별 : 정답 별 => O
# 추정확률분포 [99, 1] => 추정 별 : 정답 별 => O

# %%
fd = FlowersDataset()
fm = MlpModel('flowers_model_1', fd, [30,15,10])
fm.exec_all(epoch_count=10, report=2)
# Out:
# Model flowers_model_1 train started:
#     Epoch 2: cost=1.405, accuracy=0.372/0.340 (18/18 secs)
#     Epoch 4: cost=1.291, accuracy=0.422/0.400 (17/35 secs)
#     Epoch 6: cost=1.242, accuracy=0.446/0.350 (16/51 secs)
#     Epoch 8: cost=1.207, accuracy=0.469/0.430 (16/67 secs)
#     Epoch 10: cost=1.172, accuracy=0.480/0.430 (16/83 secs)
# Model flowers_model_1 train ended in 83 secs:
# Model flowers_model_1 test report: accuracy = 0.452, (0 secs)
#
# Model flowers_model_1 Visualization
# 추정확률분포 [56,43, 0, 1, 0, 0] => 추정 daisy : 정답 dandelion => X
# 추정확률분포 [14,13, 0,56, 0,17] => 추정 rose : 정답 dandelion => X
# 추정확률분포 [ 3,12, 0, 7,59,18] => 추정 sunflower : 정답 tulip => X

# %%
fm.visualize(5)
# Out:
# Model flowers_model_1 Visualization
# 추정확률분포 [ 1, 8, 0, 0,86, 5] => 추정 sunflower : 정답 sunflower => O
# 추정확률분포 [31,29, 0,10,12,18] => 추정 daisy : 정답 sunflower => X
# 추정확률분포 [19,21, 0,11,22,28] => 추정 tulip : 정답 tulip => O
# 추정확률분포 [58,36, 0, 4, 0, 1] => 추정 daisy : 정답 dandelion => X
# 추정확률분포 [ 5, 3, 0,42, 1,48] => 추정 tulip : 정답 tulip => O

# %%
fm2 = MlpModel('flowers_model_2', fd, [45,30,15,5])
fm2.exec_all(epoch_count=100, report=10)
# Out:
# Model flowers_model_2 train started:
#     Epoch 10: cost=1.591, accuracy=0.246/0.220 (100/100 secs)
#     Epoch 20: cost=1.206, accuracy=0.470/0.360 (123/223 secs)
#     Epoch 30: cost=1.021, accuracy=0.551/0.410 (113/336 secs)
#     Epoch 40: cost=0.836, accuracy=0.631/0.420 (112/448 secs)
#     Epoch 50: cost=0.674, accuracy=0.722/0.410 (122/570 secs)
#     Epoch 60: cost=0.540, accuracy=0.791/0.340 (102/672 secs)
#     Epoch 70: cost=0.402, accuracy=0.855/0.450 (103/775 secs)
#     Epoch 80: cost=0.351, accuracy=0.874/0.470 (105/880 secs)
#     Epoch 90: cost=0.208, accuracy=0.934/0.370 (111/991 secs)
#     Epoch 100: cost=0.138, accuracy=0.960/0.370 (119/1110 secs)
# Model flowers_model_2 train ended in 1110 secs:
# Model flowers_model_2 test report: accuracy = 0.434, (0 secs)
#
# Model flowers_model_2 Visualization
# 추정확률분포 [ 0,99, 0, 0, 1, 0] => 추정 dandelion : 정답 dandelion => O
# 추정확률분포 [ 1,19, 0, 1,60,19] => 추정 sunflower : 정답 rose => X
# 추정확률분포 [85,15, 0, 0, 0, 0] => 추정 daisy : 정답 dandelion => X

# %%
fm2.visualize(5)
# Out:
# Model flowers_model_2 Visualization
# 추정확률분포 [ 0, 0, 0, 5, 1,94] => 추정 tulip : 정답 tulip => O
# 추정확률분포 [ 2,38, 0, 0,16,45] => 추정 tulip : 정답 dandelion => X
# 추정확률분포 [ 6,94, 0, 0, 0, 0] => 추정 dandelion : 정답 daisy => X
# 추정확률분포 [55,45, 0, 0, 0, 0] => 추정 daisy : 정답 daisy => O
# 추정확률분포 [ 0, 0, 0,100, 0, 0] => 추정 rose : 정답 tulip => X
